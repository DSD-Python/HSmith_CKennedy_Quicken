# %%
#Please run to import the necessary libraries
import Project_Functions as pf
import User_Functions as uf
from datetime import date,datetime

# %%
#This cell allows us to get the necessaryb data for your 
long_term_file, new_data = uf.returning_user_start()
# Out:
# Long term file accessed successfully
# Please input the name of your bank statement file omitting the file extension:  Chase1131_Activity20221209_20230108_20240511
# Here is the data from this month
#
# ...

# %%
#Run this cell, if you succesfully completed the cell above, to access the menu
uf.Returning_User(long_term_file, new_data)
# Out:
# How can I help you?
#  A) View my Spending
#  B) Create a Budget
#  C) Compare Spending to Budget
#  D) Add Current Months Data to Long Term File
#  Q) Quit Application
# Select Here:  A
# Days of The Week    This Month  Last 3 Months  Change This Month
# Monday              16.95       18.36          -1.41
# Tuesday             23.48       20.76          2.72
# Wednesday           47.52       87.61          -40.09
# Thursday            215.51      60.34          155.17
# Friday              216.45      118.81         97.64
# Saturday            59.79       40.43          19.36
# Sunday              62.60       32.33          30.27
# Spending Categories This Month  Last 3 Months  Change This Month
# Home                0.00        16.33          -16.33
# Gifts & Donations   0.00        9.48           -9.48
# Health & Wellness   42.91       12.98          29.93
# Entertainment       0.00        27.86          -27.86
# Personal            0.00        5.92           -5.92
# ...
